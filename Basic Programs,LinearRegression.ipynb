# %%
#Print duplicates present in the given list

l=[10,20,30,10,50,20,'yu',6,'yu']
d=[]
for i in l:
  if l.count(i)>1 and i  not in d:
    d.append(i)
print(d)
# Out:
# [10, 20, 'yu']

# %%
#Print duplicates present in the given list without using any built in function
d=[]
for i in range(len(l)):
  for j in range(i+1,len(l)):
    if l[i]==l[j]:
      d.append(l[i])
print(d)
# Out:
# [10, 20, 'yu']

# %%
for j in range(5):
  for i in range(5):
    print('*',end='')
# Out:
# *************************

# %%
for j in range(5):
  print('',end='\n')
  for i in range(5):
    print('*',end='')
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
#SQUARE
for j in range(5): #This loop goes into rows
  for i in range(5): #This loop goes into columns
    print('*',end=' ') #here is space so that there is space between
  print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
#Increasing Triangle
for j in range(5):  #This loop goes into rows
  for i in range(j+1): #This loop goes into columns
    print('*',end=' ') #here is space so that there is space between each star
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
#Decreasing Triangle
for j in range(5):  #This loop goes into rows
  for i in range(j,5): #This loop goes into columns
    print('*',end=' ') #here is space so that there is space between each star
  print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
class Employee:
  comp="Dell"
  depart="Wiai"
  def wish(self):
    print("Good Morning")
    def add(self,a,b):
      return(a+b)

# %%
x=Employee()

# %%
x.comp
# Out:
# 'Dell'

# %%
x.wish()
# Out:
# Good Morning

# %%
class Employee:
  comp="LLF"
  depart="WIAT"
  def __init__ (self,name):
    print(f"{name},Welcome to LLF")
  def wish(self):
    print("Good Morning")
  def add(self,a,b):
    return(a+b)

# %%
Employee("Sonu")
# Out:
# Sonu,Welcome to LLF

# %%
class Employee:
  comp="Dell"
  depart="Wiai"
  def wish(self):
    print("Good Morning")
  def add(self,a,b):
      return(a+b)
class Employee2(Employee):
  comp="google"
  location="delhi"
  def add(self,a,b):
    return(a**2+b**2)

# %%
x=Employee()

# %%
y=Employee2()

# %%
y.comp
# Out:
# 'google'

# %%
y.location
# Out:
# 'delhi'

# %%
x.add(5,6)
# Out:
# 11

# %%
y.add(6,9)
# Out:
# 117

# %%
#Create a class with className
#Add function to add new students or remove Students
#Add function to collect email_id/contact Details
class classroom:
  def __init__(self):
    self.students=[]
    self.contacts=[]
  def add_student(self,name):
    s=name
    self.students.append(s)
  def add_contact(self,email_id):
    e=email_id
    self.contacts.append(e)
  def remove_stud(self,name):
     self.students.remove(name)

# %%
x=classroom()

# %%
x.add_student("Ayesha")

# %%
x.add_student("Pavani")

# %%
x.students
# Out:
# ['Ayesha', 'Pavani']

# %%
x.remove_stud("Pavani")

# %%
x.students
# Out:
# ['Ayesha']

# %%
#Create a shopping cart app which will take the items &
#give total bill to customers
class Shopping_cart:
  def __init__ (cart):
    cart.groceries[]
  def add_groceries(cart,items):
    s=items
    cart.
# Out:
#   File "<ipython-input-123-aa7e4a8b5e99>", line 5
#     cart.groceries[]
#                    ^
# SyntaxError: invalid syntax

# %%
from rake_nltk import Rake
rake_nltk_var=Rake()

text="""I am a programmer from India, and I am here to guide you with Data Science, Machine Learning, Python,
 and C++ for free.I hope you will learn a lot in your journey towards Coding, Machine Learning and Artificial Intelligence with me."""

rake_nltk_var.extract_keywords_from_text(text)
keyword_extracted=rake_nltk_var.get_ranked_phrases()
print(keyword_extracted)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# /usr/local/lib/python3.10/dist-packages/nltk/data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
# ...

# %%
pip install rake_nltk

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from rake_nltk import Rake

# %%
import yake
kw_extractor=yake.KeywordExtractor()
text="""I am a programmer from India, and I am here to guide you with Data Science, Machine Learning, Python,
 and C++ for free.I hope you will learn a lot in your journey towards Coding, Machine Learning and Artificial Intelligence with me."""
language="en"
max_ngram_size=3
deduplication_threshold=0.9
numOfKeywords=20
custom_kw_extractor=yake.KeywordExtractor(lan=language,n=max_ngram_size,dedupLim=deduplication_threshold,top=numOfKeywords,features=None)
keywords=custom_kw_extractor.extract_keywords(text)
for kw in keywords:
  print(kw)
# Out:
# ('Machine Learning', 0.001498944517424286)
# ('Data Science', 0.003805257902810907)
# ('Artificial Intelligence', 0.005250306307147995)
# ('programmer from India', 0.007083697249543782)
# ('journey towards Coding', 0.007083697249543782)
# ('Learning and Artificial', 0.014119149306883296)
# ('free.I hope', 0.018310930906343142)
# ('learn a lot', 0.018310930906343142)
# ('Machine', 0.02031019639918382)
# ('Python', 0.03381806651421549)
# ('Learning', 0.03679098542366414)
# ('India', 0.05245409721885829)
# ('Science', 0.05245409721885829)
# ('Coding', 0.05245409721885829)
# ('Data', 0.07226952721156656)
# ('Artificial', 0.07226952721156656)
# ('Intelligence', 0.07226952721156656)
# ('programmer', 0.13409574860218185)
# ('guide', 0.13409574860218185)
# ('free.I', 0.13409574860218185)

# %%
pip install yake
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.3 MB/s eta 0:00:00
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 36.5 MB/s eta 0:00:00
# ...

# %%
import mysql.connector

# %%
mydb=mysql.connector.connect(host='localhost',user='root',password='123456',database='python_connector')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     326         try:
# --> 327             self._cmysql.connect(**cnx_kwargs)
#     328             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (99)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-6-d6da806e22cb> in <cell line: 1>()
# ----> 1 mydb=mysql.connector.connect(host='localhost',user='root',password='Ayesha@123',database='python-connector')
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     320
#     321     if CMySQLConnection and not use_pure:
# ...

# %%
mycursor=mydb.cursor

# %%
from google.colab import drive
drive.mount('/content/citizen_pci')
# Out:
# Mounted at /content/citizen_pci

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('/content/citizen_pci.csv')
df
# Out:
#     year           pci
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
plt.scatter(df.year,df.pci)
plt.xlabel('year')
plt.ylabel('pci')
plt.show()

# %%
import sklearn.linear_model as linear_model
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df.pci)
# Out:
# LinearRegression()

# %%
reg.predict([[2030]])
# Out:
# array([49573.34484664])

# %%
plt.scatter(df.year,df.pci)
plt.plot(df.year,reg.predict(df[['year']]),color='red')
plt.xlabel('year')
plt.ylabel('pci')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv("/content/Salary_Data.csv")

# %%
df1.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df1.iloc[:10,1]#gives only salary
# Out:
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# Name: Salary, dtype: int64

# %%
x=df1.iloc[:,:-1].values  #: means all rows

# %%
print(x)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
y=df1.iloc[:,1].values
print(y)
# Out:
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
plt.plot(x,y,'c')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=10)

# %%
print("X Shape:",x.shape)
print("Y Shape:",y.shape)
print("X Train:",x_train.shape)
print("X Test:",x_test.shape)
print("Y Train:",y_train.shape)
print("Y Test:",y_test.shape)
# Out:
# X Shape: (30, 1)
# Y Shape: (30,)
# X Train: (20, 1)
# X Test: (10, 1)
# Y Train: (20,)
# Y Test: (10,)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
print(regressor.intercept_)
print(regressor.coef_)
print(regressor)
# Out:
# 25630.510121837833
# [9514.52350354]
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([ 90329.26994588,  56076.98533315,  53222.62828209,  39902.29537714,
#         44659.55712891,  93183.62699694,  64640.05648633, 116969.93575577,
#         63688.60413598,  37999.39067643])

# %%
x_test
# Out:
# array([[6.8],
#        [3.2],
#        [2.9],
#        [1.5],
#        [2. ],
#        [7.1],
#        [4.1],
#        [9.6],
#        [4. ],
#        [1.3]])

# %%
df1_x_test=pd.DataFrame(x_test)
df1_y_test=pd.DataFrame(y_test)
df1_y_pred=pd.DataFrame(y_pred)
df1_diff=df1_y_test-df1_y_pred
y_test_pred=pd.concat([df1_x_test,df1_y_test,df1_y_pred],axis=1)
y_test_pred['Differnce']=df1_diff

# %%
y_test_pred
# Out:
#      0       0              0    Differnce
# 0  6.8   91738   90329.269946  1408.730054
# 1  3.2   54445   56076.985333 -1631.985333
# 2  2.9   56642   53222.628282  3419.371718
# 3  1.5   37731   39902.295377 -2171.295377
# 4  2.0   43525   44659.557129 -1134.557129
# 5  7.1   98273   93183.626997  5089.373003
# 6  4.1   57081   64640.056486 -7559.056486
# 7  9.6  112635  116969.935756 -4334.935756
# 8  4.0   56957   63688.604136 -6731.604136
# 9  1.3   46205   37999.390676  8205.609324

# %%
df1_x_test=pd.DataFrame(x_test,columns=['Experience'])
df1_y_test=pd.DataFrame(y_test,columns=['Salary'])
df1_y_pred=pd.DataFrame(y_pred,columns=['Prediction'])
df1_diff=df1_y_test-df1_y_pred
y_test_pred=pd.concat([df1_x_test,df1_y_test,df1_y_pred],axis=1)
y_test_pred['Difference']=y_test_pred['Salary']-y_test_pred['Prediction']
y_test_pred
# Out:
#    Experience  Salary     Prediction   Difference
# 0         6.8   91738   90329.269946  1408.730054
# 1         3.2   54445   56076.985333 -1631.985333
# 2         2.9   56642   53222.628282  3419.371718
# 3         1.5   37731   39902.295377 -2171.295377
# 4         2.0   43525   44659.557129 -1134.557129
# 5         7.1   98273   93183.626997  5089.373003
# 6         4.1   57081   64640.056486 -7559.056486
# 7         9.6  112635  116969.935756 -4334.935756
# 8         4.0   56957   63688.604136 -6731.604136
# 9         1.3   46205   37999.390676  8205.609324

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9602319713033924

# %%
y_pred_f=regressor.predict(x)
y_pred_f
# Out:
# array([ 36096.48597573,  37999.39067643,  39902.29537714,  44659.55712891,
#         46562.46182961,  53222.62828209,  54174.08063244,  56076.98533315,
#         56076.98533315,  60834.24708492,  62737.15178562,  63688.60413598,
#         63688.60413598,  64640.05648633,  68445.86588775,  72251.67528916,
#         74154.57998987,  76057.48469057,  81766.19879269,  82717.65114305,
#         90329.26994588,  93183.62699694, 100795.24579976, 103649.60285082,
#        108406.86460259, 111261.22165365, 116018.48340542, 116969.93575577,
#        123630.10220825, 125533.00690896])

# %%
y_pred_final=pd.DataFrame(y_pred_f,columns=['Prediction'])
y_pred_final
# Out:
#        Prediction
# 0    36096.485976
# 1    37999.390676
# 2    39902.295377
# 3    44659.557129
# 4    46562.461830
# 5    53222.628282
# 6    54174.080632
# 7    56076.985333
# 8    56076.985333
# 9    60834.247085
# 10   62737.151786
# 11   63688.604136
# 12   63688.604136
# 13   64640.056486
# 14   68445.865888
# 15   72251.675289
# 16   74154.579990
# 17   76057.484691
# 18   81766.198793
# 19   82717.651143
# 20   90329.269946
# 21   93183.626997
# 22  100795.245800
# 23  103649.602851
# 24  108406.864603
# 25  111261.221654
# 26  116018.483405
# 27  116969.935756
# 28  123630.102208
# 29  125533.006909

# %%
result=pd.concat([df1,y_pred_final],axis=1)
result
# Out:
#     YearsExperience  Salary     Prediction
# 0               1.1   39343   36096.485976
# 1               1.3   46205   37999.390676
# 2               1.5   37731   39902.295377
# 3               2.0   43525   44659.557129
# 4               2.2   39891   46562.461830
# 5               2.9   56642   53222.628282
# 6               3.0   60150   54174.080632
# 7               3.2   54445   56076.985333
# 8               3.2   64445   56076.985333
# 9               3.7   57189   60834.247085
# 10              3.9   63218   62737.151786
# 11              4.0   55794   63688.604136
# 12              4.0   56957   63688.604136
# 13              4.1   57081   64640.056486
# 14              4.5   61111   68445.865888
# 15              4.9   67938   72251.675289
# 16              5.1   66029   74154.579990
# 17              5.3   83088   76057.484691
# 18              5.9   81363   81766.198793
# 19              6.0   93940   82717.651143
# 20              6.8   91738   90329.269946
# ...

# %%
acc=r2_score(y,y_pred_f)
acc
# Out:
# 0.9568667319430351

# %%
regressor.predict([[5]])
# Out:
# array([73203.12763951])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df2=pd.read_csv("/content/50_Startups.csv")
df2
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42  California  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68    New York  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95  California  146121.95
# 11  100671.96        91790.61        249744.55     Florida  144259.40
# ...

# %%
df2.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42  California  166187.94

# %%
x=df2.iloc[:,:-1].values
y=df2.iloc[:,4].values
print(x,y)
# Out:
# [[165349.2 136897.8 471784.1 'New York']
#  [162597.7 151377.59 443898.53 'California']
#  [153441.51 101145.55 407934.54 'Florida']
#  [144372.41 118671.85 383199.62 'New York']
#  [142107.34 91391.77 366168.42 'California']
#  [131876.9 99814.71 362861.36 'New York']
#  [134615.46 147198.87 127716.82 'California']
#  [130298.13 145530.06 323876.68 'New York']
#  [120542.52 148718.95 311613.29 'New York']
#  [123334.88 108679.17 304981.62 'California']
#  [101913.08 110594.11 229160.95 'California']
#  [100671.96 91790.61 249744.55 'Florida']
#  [93863.75 127320.38 249839.44 'California']
#  [91992.39 135495.07 252664.93 'California']
#  [119943.24 156547.42 256512.92 'Florida']
#  [114523.61 122616.84 261776.23 'New York']
#  [78013.11 121597.55 264346.06 'California']
#  [94657.16 145077.58 282574.31 'New York']
#  [91749.16 114175.79 294919.57 'New York']
#  [86419.7 153514.11 0.0 'Florida']
#  [76253.86 113867.3 298664.47 'California']
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
Label=LabelEncoder()
x[:,3]=Label.fit_transform(x[:,3])
print(x)
# Out:
# [[165349.2 136897.8 471784.1 2]
#  [162597.7 151377.59 443898.53 0]
#  [153441.51 101145.55 407934.54 1]
#  [144372.41 118671.85 383199.62 2]
#  [142107.34 91391.77 366168.42 0]
#  [131876.9 99814.71 362861.36 2]
#  [134615.46 147198.87 127716.82 0]
#  [130298.13 145530.06 323876.68 2]
#  [120542.52 148718.95 311613.29 2]
#  [123334.88 108679.17 304981.62 0]
#  [101913.08 110594.11 229160.95 0]
#  [100671.96 91790.61 249744.55 1]
#  [93863.75 127320.38 249839.44 0]
#  [91992.39 135495.07 252664.93 0]
#  [119943.24 156547.42 256512.92 1]
#  [114523.61 122616.84 261776.23 2]
#  [78013.11 121597.55 264346.06 0]
#  [94657.16 145077.58 282574.31 2]
#  [91749.16 114175.79 294919.57 2]
#  [86419.7 153514.11 0.0 1]
#  [76253.86 113867.3 298664.47 0]
#  [78389.47 153773.43 299737.29 2]
#  [73994.56 122782.75 303319.26 0]
#  [67532.53 105751.03 304768.73 0]
#  [77044.01 99281.34 140574.81 2]
#  [64664.71 139553.16 137962.62 0]
#  [75328.87 144135.98 134050.07 2]
# ...

# %%
from sklearn.compose import ColumnTransformer
ct=ColumnTransformer([('encoder',OneHotEncoder(),[3])],remainder='passthrough')
x=np.array(ct.fit_transform(x))
print(x)
# Out:
# [[0.0 0.0 1.0 165349.2 136897.8 471784.1]
#  [1.0 0.0 0.0 162597.7 151377.59 443898.53]
#  [0.0 1.0 0.0 153441.51 101145.55 407934.54]
#  [0.0 0.0 1.0 144372.41 118671.85 383199.62]
#  [1.0 0.0 0.0 142107.34 91391.77 366168.42]
#  [0.0 0.0 1.0 131876.9 99814.71 362861.36]
#  [1.0 0.0 0.0 134615.46 147198.87 127716.82]
#  [0.0 0.0 1.0 130298.13 145530.06 323876.68]
#  [0.0 0.0 1.0 120542.52 148718.95 311613.29]
#  [1.0 0.0 0.0 123334.88 108679.17 304981.62]
#  [1.0 0.0 0.0 101913.08 110594.11 229160.95]
#  [0.0 1.0 0.0 100671.96 91790.61 249744.55]
#  [1.0 0.0 0.0 93863.75 127320.38 249839.44]
#  [1.0 0.0 0.0 91992.39 135495.07 252664.93]
#  [0.0 1.0 0.0 119943.24 156547.42 256512.92]
#  [0.0 0.0 1.0 114523.61 122616.84 261776.23]
#  [1.0 0.0 0.0 78013.11 121597.55 264346.06]
#  [0.0 0.0 1.0 94657.16 145077.58 282574.31]
#  [0.0 0.0 1.0 91749.16 114175.79 294919.57]
#  [0.0 1.0 0.0 86419.7 153514.11 0.0]
#  [1.0 0.0 0.0 76253.86 113867.3 298664.47]
# ...

# %%
from sklearn.model_selection import train_test_split
train_test_split(x,y)
# Out:
# [array([[0.0, 0.0, 1.0, 120542.52, 148718.95, 311613.29],
#         [1.0, 0.0, 0.0, 134615.46, 147198.87, 127716.82],
#         [0.0, 0.0, 1.0, 144372.41, 118671.85, 383199.62],
#         [0.0, 1.0, 0.0, 86419.7, 153514.11, 0.0],
#         [0.0, 1.0, 0.0, 66051.52, 182645.56, 118148.2],
#         [0.0, 0.0, 1.0, 1000.23, 124153.04, 1903.93],
#         [0.0, 0.0, 1.0, 91749.16, 114175.79, 294919.57],
#         [0.0, 0.0, 1.0, 61994.48, 115641.28, 91131.24],
#         [1.0, 0.0, 0.0, 23640.93, 96189.63, 148001.11],
#         [0.0, 0.0, 1.0, 55493.95, 103057.49, 214634.81],
#         [1.0, 0.0, 0.0, 91992.39, 135495.07, 252664.93],
#         [0.0, 0.0, 1.0, 77044.01, 99281.34, 140574.81],
#         [0.0, 1.0, 0.0, 119943.24, 156547.42, 256512.92],
#         [0.0, 1.0, 0.0, 153441.51, 101145.55, 407934.54],
#         [1.0, 0.0, 0.0, 63408.86, 129219.61, 46085.25],
#         [1.0, 0.0, 0.0, 101913.08, 110594.11, 229160.95],
#         [1.0, 0.0, 0.0, 93863.75, 127320.38, 249839.44],
# ...

# %%
from sklearn.model_selection import train_test_split
train_test_split(x,y,test_size=0.2,random_state=14)
# Out:
# [array([[0.0, 0.0, 1.0, 28663.76, 127056.21, 201126.82],
#         [1.0, 0.0, 0.0, 22177.74, 154806.14, 28334.72],
#         [0.0, 0.0, 1.0, 94657.16, 145077.58, 282574.31],
#         [0.0, 1.0, 0.0, 100671.96, 91790.61, 249744.55],
#         [1.0, 0.0, 0.0, 38558.51, 82982.09, 174999.3],
#         [0.0, 0.0, 1.0, 65605.48, 153032.06, 107138.38],
#         [0.0, 0.0, 1.0, 61136.38, 152701.92, 88218.23],
#         [0.0, 0.0, 1.0, 91749.16, 114175.79, 294919.57],
#         [0.0, 1.0, 0.0, 46426.07, 157693.92, 210797.67],
#         [0.0, 0.0, 1.0, 46014.02, 85047.44, 205517.64],
#         [0.0, 0.0, 1.0, 114523.61, 122616.84, 261776.23],
#         [0.0, 0.0, 1.0, 144372.41, 118671.85, 383199.62],
#         [0.0, 0.0, 1.0, 1000.23, 124153.04, 1903.93],
#         [0.0, 0.0, 1.0, 120542.52, 148718.95, 311613.29],
#         [1.0, 0.0, 0.0, 123334.88, 108679.17, 304981.62],
#         [0.0, 0.0, 1.0, 72107.6, 127864.55, 353183.81],
#         [0.0, 0.0, 1.0, 542.05, 51743.15, 0.0],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=14)

# %%
from sklearn.linear_model import LinearRegression
l=LinearRegression()
l=l.fit(x_train,y_train)
l
# Out:
# LinearRegression()

# %%
y_pred=l.predict(x_test)
y_pred
# Out:
# array([ 46992.29340222, 118113.93670712, 152546.84491681,  99206.91723847,
#         87945.53013535,  77273.68551212, 118522.64975353, 189567.93038268,
#        183707.23325005, 158307.55876047])

# %%
y_test
# Out:
# array([ 42559.73, 111313.02, 132602.65,  99937.59,  89949.14,  78239.91,
#        122776.86, 191792.06, 191050.39, 156122.51])

# %%
result=pd.concat([pd.DataFrame(y_pred,columns=['Prediction']),
                  pd.DataFrame(y_test,columns=['Test'])],axis=1)
result['Difference']= result['Prediction']-result['Test']
result
# Out:
#       Prediction       Test    Difference
# 0   46992.293402   42559.73   4432.563402
# 1  118113.936707  111313.02   6800.916707
# 2  152546.844917  132602.65  19944.194917
# 3   99206.917238   99937.59   -730.672762
# 4   87945.530135   89949.14  -2003.609865
# 5   77273.685512   78239.91   -966.224488
# 6  118522.649754  122776.86  -4254.210246
# 7  189567.930383  191792.06  -2224.129617
# 8  183707.233250  191050.39  -7343.156750
# 9  158307.558760  156122.51   2185.048760

# %%
r2_score(y_test,y_pred)
# Out:
# 0.973474954355189

# %%
y_final_pred=l.predict(x)
y_final_pred
# Out:
# array([192577.5936131 , 189567.93038268, 183707.23325005, 173334.25307143,
#        171093.01766635, 162795.31959542, 158307.55876047, 160356.36676279,
#        152197.73705584, 154319.25773265, 135041.77592031, 137046.83963992,
#        129148.83111479, 127715.54946377, 152546.84491681, 146028.49357839,
#        116878.25108624, 130669.5842267 , 128743.35102725, 118522.64975353,
#        116446.53136456, 118113.93670712, 114752.71224431, 109651.22374275,
#        112669.56876675, 102616.16692774, 111033.53776076, 114631.09644782,
#        105481.00894923, 102479.60216101,  99206.91723847,  98372.14228427,
#         99052.0934655 ,  97490.44026376,  92415.21124119,  89678.59702284,
#         75592.29185814,  87945.53013535,  68505.31333552,  82859.2808048 ,
#         77273.68551212,  74023.52399789,  70137.50109257,  60414.2085062 ,
#         65504.7985268 ,  47865.59922452,  58802.27016968,  46992.29340222,
#         47574.76343749,  48292.39484897])

# %%
y_fpred=pd.DataFrame(y_final_pred,columns=['Prediction'])
result=pd.concat([df2,y_fpred],axis=1)
result['Difference']=result['Profit']-result['Prediction']
result
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42  California  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68    New York  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95  California  146121.95
# 11  100671.96        91790.61        249744.55     Florida  144259.40
# ...

# %%
r2_score(df2['Profit'],y_fpred)
# Out:
# 0.9506036891520118

# %%
#Encrption problem
#Provide the code that will encrypt the message the decrypt.
print(ord('a'))
print(chr(97))
# Out:
# 97
# a

# %%
message="Encrypt this message using python"
encrypted_message=""
for i in message.lower():
  if i.isalpha():
    encrypted_message+=chr(219-ord(i))
  elif i==" ":
    encrypted_message+="**"
  else:
    encrypted_message+=i
print(encrypted_message)
# Out:
# vmxibkg**gsrh**nvhhztv**fhrmt**kbgslm

# %%
# Out:
# [array([[0.0, 0.0, 1.0, 46014.02, 85047.44, 205517.64],
#         [0.0, 1.0, 0.0, 119943.24, 156547.42, 256512.92],
#         [0.0, 1.0, 0.0, 46426.07, 157693.92, 210797.67],
#         [1.0, 0.0, 0.0, 0.0, 135426.92, 0.0],
#         [0.0, 0.0, 1.0, 77044.01, 99281.34, 140574.81],
#         [1.0, 0.0, 0.0, 0.0, 116983.8, 45173.06],
#         [0.0, 0.0, 1.0, 65605.48, 153032.06, 107138.38],
#         [1.0, 0.0, 0.0, 23640.93, 96189.63, 148001.11],
#         [1.0, 0.0, 0.0, 91992.39, 135495.07, 252664.93],
#         [0.0, 0.0, 1.0, 28663.76, 127056.21, 201126.82],
#         [0.0, 0.0, 1.0, 542.05, 51743.15, 0.0],
#         [1.0, 0.0, 0.0, 44069.95, 51283.14, 197029.42],
#         [0.0, 1.0, 0.0, 1315.46, 115816.21, 297114.46],
#         [0.0, 0.0, 1.0, 20229.59, 65947.93, 185265.1],
#         [1.0, 0.0, 0.0, 76253.86, 113867.3, 298664.47],
#         [0.0, 0.0, 1.0, 55493.95, 103057.49, 214634.81],
#         [1.0, 0.0, 0.0, 27892.92, 84710.77, 164470.71],
# ...
